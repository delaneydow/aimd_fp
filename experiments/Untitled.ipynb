# %%
import numpy as np
from matplotlib import pyplot as plt
from helper import load_image
from inference import run_inference
from segmentation import segment_mri_slice


img = load_image("../data/sample_mri_slice.png")
mask classical = segment_mri_slice(img)
mask_quantized = run_inference("../data/sample_mri_slice.png")


plt.figure(figsize=(12,4))
plt.subplot(1,3,1); plt.imshow(img, cmap='gray'); plt.title("Input")
plt.subplot(1,3,2); plt.imshow(mask_classical); plt.title("Classical Mask")
plt.subplot(1,3,3); plt.imshow(mask_quantized); plt.title("Quantized ONNX Mask")
plt.show()
