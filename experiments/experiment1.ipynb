# %%
# In a fresh notebook cell before doing any heavy imports
# %config Application.verbose_crash=False
# %xmode Minimal
# Out:
# Requirement already satisfied: nibabel in /home/jovyan/blueberry/lib/python3.12/site-packages (5.3.3)
# Requirement already satisfied: numpy>=1.22 in /home/jovyan/blueberry/lib/python3.12/site-packages (from nibabel) (2.2.6)
# Requirement already satisfied: packaging>=20 in /home/jovyan/blueberry/lib/python3.12/site-packages (from nibabel) (25.0)
# Requirement already satisfied: typing-extensions>=4.6 in /home/jovyan/blueberry/lib/python3.12/site-packages (from nibabel) (4.15.0)
# Collecting monai
#   Using cached monai-1.5.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy<3.0,>=1.24 in /home/jovyan/blueberry/lib/python3.12/site-packages (from monai) (2.2.6)
# Requirement already satisfied: torch>=2.4.1 in /home/jovyan/blueberry/lib/python3.12/site-packages (from monai) (2.9.0)
# Requirement already satisfied: filelock in /home/jovyan/blueberry/lib/python3.12/site-packages (from torch>=2.4.1->monai) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/jovyan/blueberry/lib/python3.12/site-packages (from torch>=2.4.1->monai) (4.15.0)
# Requirement already satisfied: setuptools in /home/jovyan/blueberry/lib/python3.12/site-packages (from torch>=2.4.1->monai) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/jovyan/blueberry/lib/python3.12/site-packages (from torch>=2.4.1->monai) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/jovyan/blueberry/lib/python3.12/site-packages (from torch>=2.4.1->monai) (3.5)
# Requirement already satisfied: jinja2 in /home/jovyan/blueberry/lib/python3.12/site-packages (from torch>=2.4.1->monai) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/jovyan/blueberry/lib/python3.12/site-packages (from torch>=2.4.1->monai) (2025.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/jovyan/blueberry/lib/python3.12/site-packages (from torch>=2.4.1->monai) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/jovyan/blueberry/lib/python3.12/site-packages (from torch>=2.4.1->monai) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/jovyan/blueberry/lib/python3.12/site-packages (from torch>=2.4.1->monai) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/jovyan/blueberry/lib/python3.12/site-packages (from torch>=2.4.1->monai) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/jovyan/blueberry/lib/python3.12/site-packages (from torch>=2.4.1->monai) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/jovyan/blueberry/lib/python3.12/site-packages (from torch>=2.4.1->monai) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/jovyan/blueberry/lib/python3.12/site-packages (from torch>=2.4.1->monai) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/jovyan/blueberry/lib/python3.12/site-packages (from torch>=2.4.1->monai) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/jovyan/blueberry/lib/python3.12/site-packages (from torch>=2.4.1->monai) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/jovyan/blueberry/lib/python3.12/site-packages (from torch>=2.4.1->monai) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/jovyan/blueberry/lib/python3.12/site-packages (from torch>=2.4.1->monai) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/jovyan/blueberry/lib/python3.12/site-packages (from torch>=2.4.1->monai) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/jovyan/blueberry/lib/python3.12/site-packages (from torch>=2.4.1->monai) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/jovyan/blueberry/lib/python3.12/site-packages (from torch>=2.4.1->monai) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/jovyan/blueberry/lib/python3.12/site-packages (from torch>=2.4.1->monai) (1.13.1.3)
# Requirement already satisfied: triton==3.5.0 in /home/jovyan/blueberry/lib/python3.12/site-packages (from torch>=2.4.1->monai) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/jovyan/blueberry/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=2.4.1->monai) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/jovyan/blueberry/lib/python3.12/site-packages (from jinja2->torch>=2.4.1->monai) (3.0.3)
# Using cached monai-1.5.1-py3-none-any.whl (2.7 MB)
# Installing collected packages: monai
# Successfully installed monai-1.5.1

# %%
# ==============================
# LGG MRI Segmentation Experiment
# CPU-only, single-image proof-of-concept
# ==============================

# ------------------------------
# 1. Imports
# ------------------------------
import os
import torch
import numpy as np
import nibabel as nib
from monai.networks.nets import UNet
from monai.losses import DiceLoss
from monai.metrics import DiceMetric
from torch.utils.data import Dataset, DataLoader
from monai.transforms import Compose, EnsureChannelFirstd, ScaleIntensityd, ToTensord
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/jovyan/blueberry/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 2194, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jovyan/blueberry/lib/python3.12/site-packages/IPython/core/ultratb.py", line 1185, in structured_traceback
#   File "/home/jovyan/blueberry/lib/python3.12/site-packages/IPython/core/ultratb.py", line 1056, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jovyan/blueberry/lib/python3.12/site-packages/IPython/core/ultratb.py", line 864, in structured_traceback
#     formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
#                                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jovyan/blueberry/lib/python3.12/site-packages/IPython/core/ultratb.py", line 749, in format_exception_as_a_whole
#     records = self.get_records(etb, context, tb_offset) if etb else []
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jovyan/blueberry/lib/python3.12/site-packages/IPython/core/ultratb.py", line 806, in get_records
#     style = stack_data.style_with_executing_node(base_style, self.tb_highlight)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jovyan/blueberry/lib/python3.12/site-packages/stack_data/core.py", line 455, in style_with_executing_node
#     class NewStyle(style):
#   File "/home/jovyan/blueberry/lib/python3.12/site-packages/stack_data/core.py", line 458, in NewStyle
#     styles = {
#              ^
# MemoryError

# %%
# ------------------------------
# 2. Paths (KaggleHub cache)
# ------------------------------
DATA_ROOT = "/home/jovyan/.cache/kagglehub/datasets/mateuszbuda/lgg-mri-segmentation/versions/2"
IMAGES_DIR = os.path.join(DATA_ROOT, "kaggle_3m")          # adjust folder if necessary
LABELS_DIR = os.path.join(DATA_ROOT, "kaggle_3m_masks")    # adjust folder if necessary

# %%
# ------------------------------
# 3. Minimal Dataset Class
# ------------------------------
class SingleSliceDataset(Dataset):
    def __init__(self, images_dir, labels_dir, slice_axis=2, max_images=1):
        self.slices = []
        img_files = sorted(os.listdir(images_dir))[:max_images]
        for fname in img_files:
            img_path = os.path.join(images_dir, fname)
            mask_path = os.path.join(labels_dir, fname)
            img = nib.load(img_path).get_fdata(dtype=np.float32)
            mask = nib.load(mask_path).get_fdata(dtype=np.float32)
            mask = (mask > 0).astype(np.float32)  # normalize mask to 0/1

            # store slices along slice_axis
            for i in range(img.shape[slice_axis]):
                if slice_axis == 0:
                    self.slices.append((img[i, :, :], mask[i, :, :], fname, i))
                elif slice_axis == 1:
                    self.slices.append((img[:, i, :], mask[:, i, :], fname, i))
                else:
                    self.slices.append((img[:, :, i], mask[:, :, i], fname, i))

    def __len__(self):
        return len(self.slices)

    def __getitem__(self, idx):
        img_slice, mask_slice, fname, slice_idx = self.slices[idx]
        img_slice = np.expand_dims(img_slice, axis=0)
        mask_slice = np.expand_dims(mask_slice, axis=0)
        return {
            "image": torch.tensor(img_slice, dtype=torch.float32),
            "label": torch.tensor(mask_slice, dtype=torch.float32),
            "fname": fname,
            "slice_idx": slice_idx
        }

# %%
# ------------------------------
# 4. Prepare dataset / loader
# ------------------------------
dataset = SingleSliceDataset(IMAGES_DIR, LABELS_DIR, max_images=1)
train_loader = DataLoader(dataset, batch_size=1, shuffle=True)

# %%
# ------------------------------
# 5. Model, loss, optimizer
# ------------------------------
device = "cpu"
model = UNet(spatial_dims=2, in_channels=1, out_channels=1,
             channels=(16,32,64), strides=(2,2)).to(device)
loss_fn = DiceLoss(sigmoid=True)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
dice_metric = DiceMetric(include_background=False, reduction="mean")

# %%
# ------------------------------
# 6. Training loop
# ------------------------------
max_epochs = 5  # short for quick test
for epoch in range(max_epochs):
    model.train()
    train_loss = 0
    for batch in train_loader:
        imgs = batch["image"].to(device)
        labels = batch["label"].to(device)
        optimizer.zero_grad()
        outputs = model(imgs)
        loss = loss_fn(outputs, labels)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    train_loss /= len(train_loader)

    # --------------------------
    # Validation / Dice
    # --------------------------
    model.eval()
    val_dices = []
    with torch.no_grad():
        for batch in train_loader:  # using same batch for demo
            imgs = batch["image"].to(device)
            labels = batch["label"].to(device)
            preds = torch.sigmoid(model(imgs)) > 0.5
            dice = dice_metric(y_pred=preds, y=labels)
            val_dices.append(dice.item())
    avg_dice = np.mean(val_dices)
    print(f"Epoch {epoch+1}/{max_epochs}, Train Loss: {train_loss:.4f}, Val Dice: {avg_dice:.4f}")

# %%
# ------------------------------
# 7. Save model checkpoint
# ------------------------------
os.makedirs("./models", exist_ok=True)
torch.save(model.state_dict(), "./models/unet_cpu.pth")
print("Model saved to ./models/unet_cpu.pth")
